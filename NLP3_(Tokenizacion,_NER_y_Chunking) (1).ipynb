# %% [markdown]
# # Principales parámetros de Análisis de Lenguaje Natural
#
# Este notebook puede tomar una URL y calcular los tokens, entidades y chunks contenidos en el texto. Para esta tarea se usa la librería SpaCy.

# %%
#@title <-- 1. Presiona este botón para inicializar librerias y diccionarios

# Installs 

# !pip3 install spacy
# !python3 -m spacy download es
# !python -m spacy download es_core_news_md
# !python -m spacy.es.download all
# !pip install newspaper3k

# Imports

import urllib.request
import spacy
from spacy.lang.es.stop_words import STOP_WORDS
import requests
import newspaper
from newspaper import Article 
from collections import Counter
from matplotlib.ticker import MaxNLocator
import pandas as pd


#nlp = spacy.load('es_core_news_md')
#nlp = spacy.load('es_core_news_sm')

nlp = spacy.load('es')

# Initializations

# Add stop words in spanish
STOP_WORDS.add('y')
STOP_WORDS.add('a')
STOP_WORDS.add('o')
STOP_WORDS.add('publicidad')
STOP_WORDS.add('expansion')
STOP_WORDS.add('para')
STOP_WORDS.add('\n')

# Punctuations to clean text
punctuations = '.¡!“"”#$%&\'()*+,-/:;<=>¿?@[\\]^_`{|}~©'
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.1.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.21.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.2.2)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.1)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.0.7)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.9.6)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.2.4)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.16.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.1.0,>=7.0.8->spacy) (4.28.1)
# Collecting es_core_news_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.1.0/es_core_news_sm-2.1.0.tar.gz#egg=es_core_news_sm==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.1.0/es_core_news_sm-2.1.0.tar.gz (11.1MB)
#      |████████████████████████████████| 11.1MB 808kB/s
# Building wheels for collected packages: es-core-news-sm
#   Building wheel for es-core-news-sm (setup.py) ... done
#   Created wheel for es-core-news-sm: filename=es_core_news_sm-2.1.0-cp36-none-any.whl size=11111557 sha256=bb85c2683a34a16b5079f2cd95e7306bb4be850de7c7dca76b2d3fd9c9c2f4f8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mwswxc8h/wheels/cc/ee/c4/68922955901918a9aaa82e828d4f7ee1ccfc861285277e79b7
# Successfully built es-core-news-sm
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# Collecting es_core_news_md==2.1.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_md-2.1.0/es_core_news_md-2.1.0.tar.gz#egg=es_core_news_md==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-2.1.0/es_core_news_md-2.1.0.tar.gz (73.4MB)
#      |████████████████████████████████| 73.4MB 1.3MB/s
# Building wheels for collected packages: es-core-news-md
#   Building wheel for es-core-news-md (setup.py) ... done
#   Created wheel for es-core-news-md: filename=es_core_news_md-2.1.0-cp36-none-any.whl size=74602273 sha256=57025c884a54bb992a6c8157ab3fe1f94abb41d5323e1f20a5fe4cb38fe5f684
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m784j_rz/wheels/20/f7/6b/7a1ba56f009b05386d123ea088b56635594a046acd5cfdd2a2
# Successfully built es-core-news-md
# Installing collected packages: es-core-news-md
# Successfully installed es-core-news-md-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_md')
# /usr/bin/python3: Error while finding module specification for 'spacy.es.download' (ModuleNotFoundError: No module named 'spacy.es')
# Collecting newspaper3k
#   Downloading https://files.pythonhosted.org/packages/d7/b9/51afecb35bb61b188a4b44868001de348a0e8134b4dfa00ffc191567c4b9/newspaper3k-0.2.8-py3-none-any.whl (211kB)
#      |████████████████████████████████| 215kB 4.9MB/s
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.3.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.2.6)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.6.3)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.21.0)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading https://files.pythonhosted.org/packages/35/82/1251fefec3bb4b03fd966c7e7f7a41c9fc2bb00d823a34c13f847fd61406/feedfinder2-0.0.4.tar.gz
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading https://files.pythonhosted.org/packages/1e/90/18ac0e5340b6228c25cc8e79835c3811e7553b2b9ae87296dfeb62b7866d/tldextract-2.2.1-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 23.7MB/s
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading https://files.pythonhosted.org/packages/17/82/86982e4b6d16e4febc79c2a1d68ee3b707e8a020c5d2bc4af8052d0f136a/tinysegmenter-0.3.tar.gz
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.13)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2 (192kB)
#      |████████████████████████████████| 194kB 33.7MB/s
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.2.5)
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading https://files.pythonhosted.org/packages/a9/cb/2c8332bcdc14d33b0bedd18ae0a4981a069c3513e445120da3c3f23a8aaa/jieba3k-0.35.1.zip (7.4MB)
#      |████████████████████████████████| 7.4MB 5.4MB/s
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.5.3)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow>=3.3.0->newspaper3k) (0.46)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (2019.6.16)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (41.2.0)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading https://files.pythonhosted.org/packages/23/9c/6e63c23c39e53d3df41c77a3d05a49a42c4e1383a6d2a5e3233161b89dbf/requests_file-1.4.3-py2.py3-none-any.whl
# Building wheels for collected packages: feedfinder2, tinysegmenter, feedparser, jieba3k
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-cp36-none-any.whl size=3358 sha256=c52bbcd07fc6dab152c5bfd1df16f1f1e60ef539d0dc48e576df038b69adf7bb
#   Stored in directory: /root/.cache/pip/wheels/de/03/ca/778e3a7a627e3d98836cc890e7cb40c7575424cfd3340f40ed
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp36-none-any.whl size=13538 sha256=d813c833d64ddd703e8e48e0e1ee67f5f74a6c2ee143639581a9eef1f0db07df
#   Stored in directory: /root/.cache/pip/wheels/81/2b/43/a02ede72324dd40cdd7ca53aad718c7710628e91b8b0dc0f02
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-cp36-none-any.whl size=44940 sha256=c529d090d2c0bc24271213d0c5aa0df7314db4be208f6701555472859f5903ee
#   Stored in directory: /root/.cache/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp36-none-any.whl size=7398406 sha256=66f1b44519670d8b65658dbcbd7b3a3b6360d1e2e66fc58be55fe3cfdf67c831
#   Stored in directory: /root/.cache/pip/wheels/83/15/9c/a3f1f67e7f7181170ad37d32e503c35da20627c013f438ed34
# Successfully built feedfinder2 tinysegmenter feedparser jieba3k
# Installing collected packages: feedfinder2, requests-file, tldextract, cssselect, tinysegmenter, feedparser, jieba3k, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-5.2.1 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.4.3 tinysegmenter-0.3 tldextract-2.2.1

# %%
#@title <-- 2. Presiona este botón para enviar la URL a analizar

#@markdown Copia y pega la URL del artículo a analizar en el siguiente campo:
url = "https://expansion.mx/empresas/2019/03/20/el-tequila-gana-mas-consumidores-en-el-extranjero-que-en-mexico" #@param {type:"string"}
#@markdown 
#@markdown El proceso continúa en la siguientes celdas...

# Obtener texto limpio de la url y un doc de Spacy:
 
article = Article(url)
article.download()
article.parse()
#print(article.publish_date)  # left for debugging
#print(article.text)          # left for debugging
doc = nlp(article.text) # Runs NLP pipeline

# %% [markdown]
# # **Tokenización**
#
# La siguiente celda ejecuta una tokenización del texto contenido en el artículo. Los resultados mostrados están clasificados con atributos de palabras como los que se muestran en la siguiente lista:
#
# * **ADJ**: adjective
# * **ADP**: adposition
# * **ADV**: adverb
# * **AUX**: auxiliary verb
# * **CONJ**: coordinating conjunction
# * **DET**: determiner
# * **INTJ**: interjection
# * **NOUN**: noun
# * **NUM**: numeral
# * **PART**: particle
# * **PRON**: pronoun
# * **PROPN**: proper noun
# * **PUNCT**: punctuation
# * **SCONJ**: subordinating conjunction
# * **SYM**: symbol
# * **VERB**: verb
# * **X**: other

# %%
#@title <-- Presiona esta botón para ejecutar y mostrar los resultados de la tokenización del artículo que introdujiste
# Compute tokens from doc

words = []
for word in doc:
    words.append(
        [
        word.text.lower().strip(),
        word.lemma_.lower().strip(),
        word.shape_,
        word.pos_,
        word.tag_,
        word.idx]
    )

#tokens = [feat for feat in tokens if feat[1] not in STOP_WORDS] # Remove stop words
dfTokens=pd.DataFrame(words, columns=['word', 'lemma', 'shape', 'pos', 'tag', 'idx'])

# Clean
dfTokens = dfTokens.loc[dfTokens['pos'] != 'PUNCT'] # Remove punctuations
dfTokens = dfTokens.loc[dfTokens['pos'] != 'SPACE'] # Remove spaces
dfTokens = dfTokens.loc[dfTokens['pos'] != 'PROPN'] # Remove pronouns (stop word, or irrelevant for this NLP)
dfTokens = dfTokens.loc[dfTokens['pos'] != 'PRON'] # Remove pronouns (stop word, or irrelevant for this NLP)
dfTokens = dfTokens.loc[dfTokens['pos'] != 'ADP'] # Remove adjectives (stop word, or irrelevant for this NLP)
dfTokens = dfTokens.loc[dfTokens['pos'] != 'DET'] # Remove determiners (stop word, or irrelevant for this NLP)
dfTokens = dfTokens.loc[dfTokens['pos'] != 'CONJ'] # Remove determiners (stop word, or irrelevant for this NLP)
dfTokens = dfTokens.loc[dfTokens['pos'] != 'SCONJ'] # Remove determiners (stop word, or irrelevant for this NLP)
dfTokens # show relevant words
# Out:
#               word  ...   idx
# 0           ciudad  ...     0
# 10         últimos  ...    39
# 11            diez  ...    47
# 12            años  ...    52
# 14   exportaciones  ...    61
# 16         tequila  ...    78
# 17   incrementaron  ...    86
# 18           61.37  ...   100
# 19               %  ...   105
# 22           pasar  ...   111
# 24             138  ...   120
# 25        millones  ...   124
# 27          litros  ...   136
# 29            2008  ...   146
# 31           222.7  ...   153
# 32        millones  ...   159
# 34          cierre  ...   171
# 36            2018  ...   181
# 39         acuerdo  ...   190
# 41          cifras  ...   202
# 53         aumento  ...   255
# 55              ha  ...   267
# 56       provocado  ...   270
# 59          bebida  ...   289
# 60              ya  ...   296
# 62         consuma  ...   302
# 63             más  ...   310
# 64           fuera  ...   314
# 67       fronteras  ...   332
# 75            34.3  ...   365
# ..             ...  ...   ...
# 796        logrado  ...  4148
# 797             es  ...  4156
# 798          darle  ...  4159
# 800        sentido  ...  4168
# 801            más  ...  4176
# 802       nacional  ...  4180
# 804      doméstico  ...  4191
# 807             ha  ...  4207
# 808      levantado  ...  4210
# 809            más  ...  4220
# 810        interés  ...  4224
# 813   asociaciones  ...  4241
# 815     participar  ...  4259
# 818          habla  ...  4274
# 825       bondades  ...  4304
# 827          tiene  ...  4317
# 829           país  ...  4331
# 832        tequila  ...  4341
# 837    caracteriza  ...  4365
# 840   versatilidad  ...  4384
# 842           hace  ...  4401
# 844            sea  ...  4410
# 845   mundialmente  ...  4414
# 846            tan  ...  4427
# 847      respetado  ...  4431
# 849     reconocido  ...  4443
# 852        bebidas  ...  4461
# 853         tienen  ...  4469
# 855     cualidades  ...  4481
# 858          añade  ...  4494
#
# [355 rows x 6 columns]

# %% [markdown]
# # **Named Entity Recognition (NER)**
#
# NER es probablemente el primer paso hacia la extracción de información que busca ubicar y clasificar las entidades nombradas en el texto en categorías predefinidas, como los nombres de personas, organizaciones, ubicaciones, expresiones de tiempos, cantidades, valores monetarios, porcentajes, etc. Se utiliza NER en muchos campos del Procesamiento del lenguaje natural (PNL), y puede ayudar a responder muchas preguntas del mundo real, como:
#
# * ¿Qué empresas se mencionaron en el reportaje?
# * ¿Se mencionaron los productos especificados en las quejas o revisiones?
# * ¿El tweet contiene el nombre de una persona? ¿El tweet contiene la ubicación de esta persona?
#
# Clasificaciones de SpaCy:
#
# * **PERSON**	People, including fictional.
# * **NORP**	Nationalities or religious or political groups.
# * **FAC**	Buildings, airports, highways, bridges, etc.
# * **ORG**	Companies, agencies, institutions, etc.
# * **GPE**	Countries, cities, states.
# * **LOC**	Non-GPE locations, mountain ranges, bodies of water.
# * **PRODUCT**	Objects, vehicles, foods, etc. (Not services.)
# * **EVENT**	Named hurricanes, battles, wars, sports events, etc.
# * **WORK_OF_ART**	Titles of books, songs, etc.
# * **LAW**	Named documents made into laws.
# * **LANGUAGE**	Any named language.
# * **DATE**	Absolute or relative dates or periods.
# * **TIME**	Times smaller than a day.
# * **PERCENT**	Percentage, including "%".
# * **MONEY**	Monetary values, including unit.
# * **QUANTITY**	Measurements, as of weight or distance.
# * **ORDINAL**	"first", "second", etc.
# * **CARDINAL**	Numerals that do not fall under another type.

# %%
#@title <-- Presiona este botón para calcular y mostrar las entidades reconocidas en el texto
# Computer NERs from doc: 

ners = []
for ent in doc.ents:
    ners.append(
        [
            ent.text.strip(),
            ent.label_,
            ent.lemma_.strip()
        ]
    )
    
dfNER = pd.DataFrame(ners, columns=['name', 'label', 'lemma_'])

# Clean
dfNER = dfNER.loc[dfNER['name'] != '']
#dfNER = dfNER.loc[dfNER['label'] == 'ORG']
dfNER
# Out:
#                                          name  ...                                     lemma_
# 0                                      MÉXICO  ...                                     MÉXICO
# 1                                   Expansión  ...                                  Expansión
# 2                    En los últimos diez años  ...                      En lo último diez año
# 3               Cámara Reguladora del Tequila  ...              Cámara Reguladora del Tequila
# 4                                         CRT  ...                                        CRT
# 5                              Un aumento que  ...                            Un aumentar que
# 6                                      México  ...                                     México
# 7               El principal mercado exterior  ...               El principal mercar exterior
# 8                              Estados Unidos  ...                             Estados Unidos
# 9                                    Alemania  ...                                   Alemania
# 10                                     España  ...                                     España
# 11                                    Francia  ...                                    Francia
# 12                                Reino Unido  ...                                Reino Unido
# 13                                      ISCAM  ...                                      ISCAM
# 14                                     Países  ...                                     Países
# 15                                   Colombia  ...                                   Colombia
# 16                                  Sudáfrica  ...                                  Sudáfrica
# 17                 Esta creciente popularidad  ...                 Esta creciente popularidad
# 18                              Horacio Núñez  ...                              Horacio Núñez
# 19                     Consejeros Comerciales  ...                     Consejeros Comerciales
# 20                                      ISCAM  ...                                      ISCAM
# 21                                        Lee  ...                                        Lee
# 22                                Jose Cuervo  ...                                Jose Cuervo
# 23                                      Sauza  ...                                      Sauza
# 24                              “La categoría  ...                             “ La categoría
# 25                                Por un lado  ...                               Por uno lado
# 26                                      Nuñez  ...                                      Nuñez
# 27                                 Publicidad  ...                                 Publicidad
# 28                                  Don Julio  ...                                  Don Julio
# 29                                     Diageo  ...                                     Diageo
# ..                                        ...  ...                                        ...
# 52                              Erik Seiersen  ...                              Erik Seiersen
# 53                              Diageo México  ...                              Diageo México
# 54                       Recomendamos: Brasil  ...                      Recomendamos : Brasil
# 55         Parte de la estrategia de la firma  ...        Parte de lo estrategia de lo firmar
# 56                                   Beam Inc  ...                                   Beam Inc
# 57                           Suntory Holdings  ...                           Suntory Holdings
# 58                                     México  ...                                     México
# 59                                       —que  ...                                       —que
# 60                                    México—  ...                                    México—
# 61                                      Sauza  ...                                      Sauza
# 62                                   Hornitos  ...                                   Hornitos
# 63                                 Casa Sauza  ...                                 Casa Sauza
# 64                                          ”  ...                                          ”
# 65                           Rodolfo González  ...                           Rodolfo González
# 66  Cámara Nacional de la Industria Tequilera  ...  Cámara Nacional de lo Industria Tequilera
# 67                               Por su parte  ...                              Por su partir
# 68                                Jose Cuervo  ...                                Jose Cuervo
# 69                              La producción  ...                              La producción
# 70                                     México  ...                                     México
# 71                                     México  ...                                     México
# 72                                    Jalisco  ...                                    Jalisco
# 73                                 Guanajuato  ...                                 Guanajuato
# 74                                  Michoacán  ...                                  Michoacán
# 75                                    Nayarit  ...                                    Nayarit
# 76                                 Tamaulipas  ...                                 Tamaulipas
# 77                La fuerza de esta categoría  ...                La forzar de este categoría
# 78             Día Nacional del Tequila.“Aquí  ...             Día Nacional del Tequila.“Aquí
# 79                                     México  ...                                     México
# 80                              Pocas bebidas  ...                               Pocas bebida
# 81                                   González  ...                                   González
#
# [82 rows x 3 columns]

# %%
#@title <-- Presiona este botón para mostrar el conteo entidades por categoría
# Counts number of attributes in doc

labels = [x.label_ for x in doc.ents]
Counter(labels)
# Out:
# Counter({'LOC': 34, 'MISC': 24, 'ORG': 5, 'PER': 19})

# %%
#@title <-- Presiona este botón para mostrar las entidades que aparecen con mayor frecuencia
# Most used entities

items = [x.text for x in doc.ents]
items = [x.strip() for x in items]
items = [x for x in items if x != '']
Counter(items).most_common(5)
# Out:
# [('México', 6),
#  ('Sauza', 3),
#  ('Don Julio', 3),
#  ('Reino Unido', 2),
#  ('ISCAM', 2)]

# %% [markdown]
# # **Chunking**
#
# Chunking consiste en identificar sustantivos en un texto y expresarlos junto con las palabras que le describen. Por ejemplo, en la frase: “Vivía en la casa de rejas verdes.” podemos encontrar los siguientes chunks:
# - La casa de rejas verdes
# - La casa
# - Rejas verdes

# %%
#@title <-- Presiona este botón para mostrar los Chunks encontrados en el documento
# Document Chunks

# al parecer no funciona la clasificacion en español, 
# todos los chunks aparecen clasificados como 'NP'

chunking = []
for chunk in doc.noun_chunks:
    chunking.append(
        [
            chunk.text.strip(),
            chunk.label_,
            chunk.root.text,
            chunk.lemma_
        ]
    )
dfChunk = pd.DataFrame(chunking, columns = ['phrase', 'label', 'root', 'lemma'])
    #print(chunk.text, '|', chunk.label_, '|', chunk.root.text, '|', chunk.lemma_)
dfChunk
# Out:
#                                phrase  ...                             lemma
# 0                              CIUDAD  ...                            CIUDAD
# 1                              MÉXICO  ...                            MÉXICO
# 2                           Expansión  ...                         Expansión
# 3               los últimos diez años  ...                lo último diez año
# 4                   las exportaciones  ...                   los exportación
# 5                             tequila  ...                           tequila
# 6                               61.37  ...                             61.37
# 7                            millones  ...                            millón
# 8                              litros  ...                             litro
# 9                                2008  ...                              2008
# 10                           millones  ...                            millón
# 11                             cierre  ...                            cerrar
# 12                               2018  ...                              2018
# 13                            acuerdo  ...                           acordar
# 14                             cifras  ...                            cifrar
# 15   la Cámara Reguladora del Tequila  ...  lo Cámara Reguladora del Tequila
# 16                                CRT  ...                               CRT
# 17                         Un aumento  ...                       Un aumentar
# 18                                que  ...                               que
# 19                        esta bebida  ...                        este beber
# 20                                 se  ...                                se
# 21                 nuestras fronteras  ...                  nuestro frontero
# 22                                que  ...                               que
# 23                             México  ...                            México
# 24                           millones  ...                            millón
# 25                              cajas  ...                              caja
# 26                             litros  ...                             litro
# 27                                que  ...                               que
# 28                                 se  ...                                se
# 29                               2018  ...                              2018
# ..                                ...  ...                               ...
# 232                        proporción  ...                        proporción
# 233                        Guanajuato  ...                        Guanajuato
# 234                         Michoacán  ...                         Michoacán
# 235                           Nayarit  ...                           Nayarit
# 236                        Tamaulipas  ...                        Tamaulipas
# 237                           empleos  ...                            empleo
# 238                         La fuerza  ...                         La forzar
# 239                    esta categoría  ...                    este categoría
# 240                             marzo  ...                             marzo
# 241                                se  ...                                se
# 242            el primer Día Nacional  ...                el ﻿1 Día Nacional
# 243                     Tequila.“Aquí  ...                     Tequila.“Aquí
# 244                               que  ...                               que
# 245                        un sentido  ...                        uno sentir
# 246                           interés  ...                           interés
# 247                otras asociaciones  ...                   otro asociación
# 248                                Se  ...                                Se
# 249                            México  ...                            México
# 250                      las bondades  ...                        los bondad
# 251                               que  ...                               que
# 252                      nuestro país  ...                      nuestro país
# 253                        el tequila  ...                        el tequila
# 254                             ellos  ...                             ellos
# 255                                se  ...                                se
# 256                   la versatilidad  ...                   lo versatilidad
# 257                               que  ...                               que
# 258                     Pocas bebidas  ...                      Pocas bebida
# 259                   esas cualidades  ...                      ese cualidad
# 260                                 ”  ...                                 ”
# 261                          González  ...                          González
#
# [262 rows x 4 columns]

# %% [markdown]
# # Dependency Parsing
#
# Un analizador de dependencia analiza la estructura gramatical de una oración, estableciendo relaciones entre la palabra principal y las palabras que modifican a esa palabra principal.

# %%
#@title <-- Presiona este botón para mostrar las dependencias encontradas en el documento

for token in doc:
    print("{0}/{1} <--{2}-- {3}/{4}".format(
        token.text, '|', token.tag_, '|', token.dep_, '|', token.head.text, '|', token.head.tag_))
# Out:
# CIUDAD/| <--NOUN__Gender=Masc|Number=Sing-- |/ROOT
# DE/| <--ADP__AdpType=Prep-- |/case
# MÉXICO/| <--PROPN___-- |/nmod
# (/| <--PUNCT__PunctSide=Ini|PunctType=Brck-- |/punct
# Expansión/| <--PROPN___-- |/appos
# )/| <--PUNCT__PunctSide=Fin|PunctType=Brck-- |/punct
# ./| <--PUNCT__PunctType=Peri-- |/punct
# -/| <--PUNCT__PunctType=Dash-- |/punct
# En/| <--ADP__AdpType=Prep-- |/case
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# últimos/| <--ADJ__Gender=Masc|Number=Plur|NumType=Ord-- |/amod
# diez/| <--NUM__Number=Plur|NumType=Card-- |/nummod
# años/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# exportaciones/| <--NOUN__Gender=Fem|Number=Plur-- |/nsubj
# de/| <--ADP__AdpType=Prep-- |/case
# tequila/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# incrementaron/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin-- |/ROOT
# 61.37/| <--NOUN__AdvType=Tim-- |/obj
# %/| <--SYM__NumForm=Digit|NumType=Frac-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# al/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/mark
# pasar/| <--VERB__VerbForm=Inf-- |/advcl
# de/| <--ADP__AdpType=Prep-- |/case
# 138/| <--NUM__NumForm=Digit-- |/nummod
# millones/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# de/| <--ADP__AdpType=Prep-- |/case
# litros/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# en/| <--ADP__AdpType=Prep-- |/case
# 2008/| <--NOUN__AdvType=Tim-- |/obl
# a/| <--ADP__AdpType=Prep-- |/case
# 222.7/| <--NUM__NumForm=Digit-- |/nummod
# millones/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# al/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# cierre/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# 2018/| <--NOUN__AdvType=Tim-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# de/| <--ADP__AdpType=Prep-- |/case
# acuerdo/| <--NOUN___-- |/fixed
# con/| <--ADP__AdpType=Prep-- |/fixed
# cifras/| <--NOUN__Gender=Fem|Number=Plur-- |/obl
# de/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# Cámara/| <--PROPN___-- |/nmod
# Reguladora/| <--PROPN___-- |/flat
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# Tequila/| <--PROPN___-- |/flat
# (/| <--PUNCT__PunctSide=Ini|PunctType=Brck-- |/punct
# CRT/| <--PROPN___-- |/flat
# )/| <--PUNCT__PunctSide=Fin|PunctType=Brck-- |/punct
# ./| <--PUNCT__PunctType=Peri-- |/punct
# Un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# aumento/| <--NOUN__Gender=Masc|Number=Sing-- |/ROOT
# que/| <--PRON__PronType=Rel-- |/nsubj
# ha/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# provocado/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/acl
# que/| <--SCONJ___-- |/mark
# esta/| <--DET__Gender=Fem|Number=Sing|PronType=Dem-- |/det
# bebida/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
# ya/| <--ADV___-- |/advmod
# se/| <--PRON__Person=3-- |/obj
# consuma/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ccomp
# más/| <--ADV___-- |/advmod
# fuera/| <--ADV___-- |/advmod
# de/| <--ADP__AdpType=Prep-- |/case
# nuestras/| <--DET__Gender=Fem|Number=Plur|Number[psor]=Plur|Person=1|Poss=Yes|PronType=Prs-- |/det
# fronteras/| <--NOUN__Gender=Fem|Number=Plur-- |/obl
# que/| <--PRON__PronType=Rel-- |/mark
# en/| <--ADP__AdpType=Prep-- |/case
# México/| <--PROPN___-- |/nmod
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# De/| <--ADP__AdpType=Prep-- |/case
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# 34.3/| <--NUM__NumForm=Digit-- |/nummod
# millones/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# de/| <--ADP__AdpType=Prep-- |/case
# cajas/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# nueve/| <--NUM__Number=Plur|NumType=Card-- |/nummod
# litros/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# que/| <--PRON__PronType=Rel-- |/nsubj
# se/| <--PRON__Person=3-- |/obj
# produjeron/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin-- |/acl
# en/| <--ADP__AdpType=Prep-- |/case
# 2018/| <--NOUN__AdvType=Tim-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# 24.9/| <--NUM__NumForm=Digit-- |/nummod
# millones/| <--NOUN__Gender=Masc|Number=Plur-- |/nsubj
# se/| <--PRON__Person=3-- |/obj
# exportaron/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin-- |/ROOT
# y/| <--CCONJ___-- |/cc
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# resto/| <--NOUN__Gender=Masc|Number=Sing-- |/nsubj
# se/| <--PRON__Person=3-- |/obj
# destinó/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/conj
# al/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# mercado/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# nacional/| <--ADJ__Number=Sing-- |/amod
# ./| <--PUNCT__PunctType=Peri-- |/punct
# El/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# principal/| <--ADJ__Number=Sing-- |/amod
# mercado/| <--NOUN__Gender=Masc|Number=Sing-- |/nsubj
# exterior/| <--ADJ__Number=Sing-- |/amod
# es/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/cop
# Estados/| <--PROPN___-- |/ROOT
# Unidos/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# que/| <--PRON__PronType=Rel-- |/nsubj
# recibe/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/acl
# 83/| <--NUM__NumForm=Digit-- |/obj
# %/| <--SYM__NumForm=Digit|NumType=Frac-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# exportaciones/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# seguido/| <--ADJ__Gender=Masc|Number=Sing|VerbForm=Part-- |/advmod
# por/| <--ADP__AdpType=Prep-- |/case
# Alemania/| <--PROPN___-- |/obj
# con/| <--ADP__AdpType=Prep-- |/case
# un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# 2.5/| <--NUM__NumForm=Digit|NumType=Card-- |/obl
# %/| <--SYM__NumForm=Digit|NumType=Frac-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# España/| <--PROPN___-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# Francia/| <--PROPN___-- |/conj
# y/| <--CCONJ___-- |/cc
# Reino/| <--PROPN___-- |/conj
# Unido/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# según/| <--ADP__AdpType=Prep-- |/case
# datos/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# ISCAM/| <--PROPN___-- |/nmod
# ./| <--PUNCT__PunctType=Peri-- |/punct
# Países/| <--NOUN__Gender=Masc|Number=Plur-- |/nsubj
# como/| <--SCONJ___-- |/mark
# Colombia/| <--PROPN___-- |/nmod
# y/| <--CCONJ___-- |/cc
# Sudáfrica/| <--PROPN___-- |/conj
# comienzan/| <--AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# a/| <--ADP__AdpType=Prep-- |/case
# ser/| <--AUX__VerbForm=Inf-- |/cop
# relevantes/| <--ADJ__Number=Plur-- |/ROOT
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# Esta/| <--DET__Gender=Fem|Number=Sing|PronType=Dem-- |/det
# creciente/| <--ADJ__Number=Sing-- |/amod
# popularidad/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
# se/| <--PRON___-- |/obj
# debe/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# principalmente/| <--ADV___-- |/advmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# a/| <--ADP__AdpType=Prep-- |/case
# una/| <--DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art-- |/det
# tendencia/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# mundial/| <--ADJ__Number=Sing-- |/amod
# por/| <--ADP__AdpType=Prep-- |/mark
# consumir/| <--VERB__VerbForm=Inf-- |/acl
# bebidas/| <--NOUN__Gender=Fem|Number=Plur-- |/obj
# artesanales/| <--ADJ__Number=Plur-- |/amod
# y/| <--CCONJ___-- |/cc
# a/| <--ADP__AdpType=Prep-- |/case
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# productos/| <--NOUN__Gender=Masc|Number=Plur-- |/conj
# ‘/| <--ADJ__Gender=Masc|Number=Sing-- |/amod
# premium/| <--NOUN__Gender=Masc|Number=Sing-- |/amod
# ’/| <--ADJ__Gender=Masc|Number=Sing-- |/amod
# que/| <--SCONJ___-- |/obj
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# empresas/| <--NOUN__Gender=Fem|Number=Plur-- |/nsubj
# han/| <--AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# lanzando/| <--VERB__VerbForm=Ger-- |/acl
# en/| <--ADP__AdpType=Prep-- |/case
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# últimos/| <--ADJ__Gender=Masc|Number=Plur|NumType=Ord-- |/amod
# diez/| <--NUM__Number=Plur|NumType=Card-- |/nummod
# años/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# como/| <--SCONJ___-- |/mark
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# tequilas/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# cristalinos/| <--ADJ__Gender=Masc|Number=Plur-- |/amod
# o/| <--CCONJ___-- |/cc
# blancos/| <--ADJ__Gender=Masc|Number=Plur-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# comenta/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ccomp
# Horacio/| <--PROPN___-- |/nsubj
# Núñez/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# socio/| <--NOUN__Gender=Masc|Number=Sing-- |/appos
# de/| <--ADP__AdpType=Prep-- |/case
# Consejeros/| <--PROPN___-- |/nmod
# Comerciales/| <--PROPN___-- |/flat
# (/| <--PUNCT__PunctSide=Ini|PunctType=Brck-- |/punct
# ISCAM/| <--PROPN___-- |/flat
# )/| <--PUNCT__PunctSide=Fin|PunctType=Brck-- |/punct
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# Lee/| <--PROPN___-- |/nsubj
# :/| <--PUNCT__PunctType=Colo-- |/punct
# Jose/| <--PROPN___-- |/appos
# Cuervo/| <--PROPN___-- |/flat
# y/| <--CCONJ___-- |/cc
# Sauza/| <--PROPN___-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# tequilas/| <--NOUN__Gender=Masc|Number=Plur-- |/appos
# más/| <--ADV___-- |/advmod
# vendidos/| <--ADJ__Gender=Masc|Number=Plur|VerbForm=Part-- |/amod
# en/| <--ADP__AdpType=Prep-- |/case
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# mundo/| <--NOUN__Gender=Masc|Number=Sing-- |/obl
#
#
# /| <--_SP-- |/
# “/| <--PROPN___-- |/appos
# La/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# categoría/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
# estaba/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin-- |/aux
# siendo/| <--AUX__VerbForm=Ger-- |/cop
# muy/| <--ADV___-- |/advmod
# tradicional/| <--ADJ__Number=Sing-- |/ROOT
# y/| <--CCONJ___-- |/cc
# se/| <--PRON__Person=3-- |/obj
# había/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin-- |/aux
# perdido/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/conj
# un/| <--DET__Gender=Masc|Number=Sing|PronType=Art-- |/advmod
# poco/| <--ADV___-- |/fixed
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# innovación/| <--NOUN__Gender=Fem|Number=Sing-- |/obj
# y/| <--CCONJ___-- |/cc
# con/| <--ADP__AdpType=Prep-- |/case
# estas/| <--DET__Gender=Fem|Number=Plur|PronType=Dem-- |/det
# dos/| <--NUM__Number=Plur|NumType=Card-- |/nummod
# innovaciones/| <--NOUN__Gender=Fem|Number=Plur-- |/obl
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# producto/| <--NOUN__Gender=Masc|Number=Sing-- |/nsubj
# vuelve/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# a/| <--ADP__AdpType=Prep-- |/mark
# tomar/| <--VERB__VerbForm=Inf-- |/conj
# relevancia/| <--NOUN__Gender=Fem|Number=Sing-- |/obj
# ./| <--PUNCT__PunctType=Peri-- |/punct
# Por/| <--ADP__AdpType=Prep-- |/case
# un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# lado/| <--NOUN__Gender=Masc|Number=Sing-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# tequilas/| <--NOUN__Gender=Masc|Number=Plur-- |/nsubj
# cristalinos/| <--ADJ__Gender=Masc|Number=Plur-- |/amod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# que/| <--PRON__PronType=Rel-- |/nsubj
# son/| <--AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/cop
# tanto/| <--ADV___-- |/advmod
# reposados/| <--ADJ__Gender=Masc|Number=Plur-- |/acl
# como/| <--SCONJ___-- |/mark
# añejos/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# con/| <--ADP__AdpType=Prep-- |/case
# sabor/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# suave/| <--ADJ__Number=Sing-- |/amod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# y/| <--CCONJ___-- |/cc
# botellas/| <--NOUN__Gender=Fem|Number=Plur-- |/conj
# premium/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/amod
# atrajeron/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin-- |/ccomp
# a/| <--ADP__AdpType=Prep-- |/case
# adultos/| <--NOUN__Gender=Masc|Number=Plur-- |/obj
# jóvenes/| <--ADJ__Number=Plur-- |/amod
# y/| <--CCONJ___-- |/cc
# a/| <--ADP__AdpType=Prep-- |/case
# mujeres/| <--NOUN__Gender=Fem|Number=Plur-- |/conj
# ;/| <--PUNCT__PunctType=Semi-- |/punct
# y/| <--CCONJ___-- |/cc
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# por/| <--ADP__AdpType=Prep-- |/advmod
# otro/| <--ADJ___-- |/fixed
# lado/| <--NOUN___-- |/fixed
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# blancos/| <--NOUN__Gender=Masc|Number=Plur-- |/nsubj
# que/| <--PRON__PronType=Rel-- |/nsubj
# salen/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/acl
# directo/| <--ADJ__Gender=Masc|Number=Sing-- |/obj
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# destilado/| <--NOUN__Gender=Masc|Number=Sing-- |/obl
# tienen/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/conj
# una/| <--DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art-- |/det
# gran/| <--ADJ__Number=Sing-- |/amod
# calidad/| <--NOUN__Gender=Fem|Number=Sing-- |/obj
# ”/| <--PROPN___-- |/amod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# añade/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# Nuñez/| <--PROPN___-- |/nsubj
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# Publicidad/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
#
#
# /| <--_SP-- |/
# En/| <--ADP__AdpType=Prep-- |/case
# manos/| <--NOUN___-- |/fixed
# de/| <--ADP__AdpType=Prep-- |/fixed
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# multinacionales/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
#
#
# /| <--_SP-- |/
# Uno/| <--PRON__Gender=Masc|Number=Sing|PronType=Ind-- |/appos
# de/| <--ADP__AdpType=Prep-- |/case
# los/| <--DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art-- |/det
# factores/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# principales/| <--ADJ__Number=Plur-- |/amod
# que/| <--PRON__PronType=Rel-- |/nsubj
# ha/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# permitido/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/acl
# que/| <--SCONJ___-- |/mark
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# tequila/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
# se/| <--PRON__Person=3-- |/obj
# encuentre/| <--VERB__Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ccomp
# en/| <--ADP__AdpType=Prep-- |/case
# más/| <--ADV___-- |/advmod
# de/| <--ADP__AdpType=Prep-- |/case
# 120/| <--NUM__NumForm=Digit-- |/nummod
# países/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# es/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/cop
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# compra/| <--NOUN__Gender=Fem|Number=Sing-- |/ROOT
# de/| <--ADP__AdpType=Prep-- |/case
# algunas/| <--DET__Gender=Fem|Number=Plur|PronType=Ind-- |/det
# marcas/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
# por/| <--ADP__AdpType=Prep-- |/case
# parte/| <--NOUN___-- |/fixed
# de/| <--ADP__AdpType=Prep-- |/fixed
# empresas/| <--NOUN__Gender=Fem|Number=Plur-- |/obl
# multinacionales/| <--ADJ__Number=Plur-- |/amod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# como/| <--SCONJ___-- |/mark
# es/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/cop
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# caso/| <--NOUN__Gender=Masc|Number=Sing-- |/advcl
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# tequila/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# Don/| <--PROPN___-- |/appos
# Julio/| <--PROPN___-- |/flat
# que/| <--PRON__PronType=Rel-- |/obj
# adquirió/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/acl
# Diageo/| <--PROPN___-- |/obj
# en/| <--ADP__AdpType=Prep-- |/case
# 2014/| <--NOUN__AdvType=Tim-- |/obl
# ;/| <--PUNCT__PunctType=Semi-- |/punct
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# tequila/| <--PROPN___-- |/appos
# Sauza/| <--PROPN___-- |/appos
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# por/| <--ADP__AdpType=Prep-- |/case
# parte/| <--NOUN___-- |/fixed
# de/| <--ADP__AdpType=Prep-- |/fixed
# Beam/| <--PROPN___-- |/nmod
# Suntory/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# también/| <--ADV___-- |/advmod
# en/| <--ADP__AdpType=Prep-- |/case
# 2014/| <--NOUN__AdvType=Tim-- |/nmod
# ;/| <--PUNCT__PunctType=Semi-- |/punct
# y/| <--CCONJ___-- |/cc
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# compra/| <--NOUN__Gender=Fem|Number=Sing-- |/conj
# de/| <--ADP__AdpType=Prep-- |/case
# Patrón/| <--PROPN___-- |/nmod
# por/| <--ADP__AdpType=Prep-- |/case
# Bacardi/| <--PROPN___-- |/nmod
# en/| <--ADP__AdpType=Prep-- |/case
# 2018/| <--NOUN__AdvType=Tim-- |/nmod
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# “/| <--PROPN___-- |/obj
# Si/| <--SCONJ___-- |/mark
# bien/| <--ADV___-- |/fixed
# Patrón/| <--PROPN___-- |/nsubj
# ya/| <--ADV___-- |/advmod
# tenia/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/amod
# presencia/| <--NOUN__Gender=Fem|Number=Sing-- |/acl
# en/| <--ADP__AdpType=Prep-- |/case
# muchos/| <--DET__Gender=Masc|Number=Plur|PronType=Ind-- |/det
# mercados/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# internacionales/| <--ADJ__Number=Plur-- |/amod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# hoy/| <--ADV___-- |/advmod
# con/| <--ADP__AdpType=Prep-- |/case
# toda/| <--DET__Gender=Fem|Number=Sing|PronType=Ind-- |/det
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# estructura/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# que/| <--PRON__PronType=Rel-- |/obj
# tiene/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/acl
# Bacardi/| <--PROPN___-- |/nsubj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# hemos/| <--AUX__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin-- |/aux
# visto/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/acl
# un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# aumento/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# en/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# demanda/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# manera/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# considerable/| <--ADJ__Number=Sing-- |/amod
# en/| <--ADP__AdpType=Prep-- |/case
# Reino/| <--PROPN___-- |/nmod
# Unido/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# Japón/| <--PROPN___-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# Australia/| <--PROPN___-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# Colombia/| <--PROPN___-- |/conj
# e/| <--CCONJ___-- |/cc
# incluso/| <--ADV___-- |/conj
# en/| <--ADP__AdpType=Prep-- |/case
# Sudáfrica/| <--PROPN___-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# a/| <--ADP__AdpType=Prep-- |/mark
# pesar/| <--NOUN___-- |/fixed
# de/| <--ADP__AdpType=Prep-- |/fixed
# que/| <--SCONJ___-- |/fixed
# en/| <--ADP__AdpType=Prep-- |/case
# Estados/| <--PROPN___-- |/obl
# Unidos/| <--PROPN___-- |/flat
# se/| <--PRON___-- |/obj
# venden/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/advcl
# seis/| <--NUM__Number=Plur|NumType=Card-- |/nummod
# o/| <--CCONJ___-- |/cc
# siete/| <--NUM__Number=Plur|NumType=Card-- |/conj
# tequilas/| <--NOUN__Gender=Fem|Number=Plur-- |/nsubj
# de/| <--ADP__AdpType=Prep-- |/case
# cada/| <--DET__Number=Sing|PronType=Ind-- |/det
# 10/| <--NUM__NumForm=Digit|NumType=Card-- |/nummod
# que/| <--PRON__PronType=Rel-- |/nsubj
# consumen/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/advcl
# ”/| <--PROPN___-- |/obj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# explica/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# Francisco/| <--PROPN___-- |/nsubj
# Soltero/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# director/| <--NOUN__Gender=Masc|Number=Sing-- |/appos
# de/| <--ADP__AdpType=Prep-- |/case
# Planeación/| <--PROPN___-- |/nmod
# Estratégica/| <--PROPN___-- |/flat
# y/| <--CCONJ___-- |/cc
# Asuntos/| <--PROPN___-- |/conj
# Institucionales/| <--PROPN___-- |/flat
# en/| <--ADP__AdpType=Prep-- |/case
# Patrón/| <--PROPN___-- |/nmod
# México/| <--PROPN___-- |/flat
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# Por/| <--ADP__AdpType=Prep-- |/case
# su/| <--DET__Number=Sing|Person=3|Poss=Yes|PronType=Prs-- |/det
# parte/| <--NOUN__Gender=Fem|Number=Sing-- |/obl
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# empresa/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
# británica/| <--ADJ__Gender=Fem|Number=Sing-- |/amod
# Diageo/| <--PROPN___-- |/appos
# ha/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# logrado/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/ROOT
# por/| <--ADP__AdpType=Prep-- |/case
# cuarto/| <--ADJ__Gender=Masc|Number=Sing|NumType=Ord-- |/amod
# año/| <--NOUN__Gender=Masc|Number=Sing-- |/obl
# consecutivo/| <--ADJ__Gender=Masc|Number=Sing-- |/amod
# un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# crecimiento/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# a/| <--ADP__AdpType=Prep-- |/case
# doble/| <--ADJ__Number=Sing-- |/amod
# dígito/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# Don/| <--PROPN___-- |/nmod
# Julio/| <--PROPN___-- |/flat
# ./| <--PUNCT__PunctType=Peri-- |/punct
# “/| <--PROPN___-- |/nsubj
# Tequila/| <--PROPN___-- |/flat
# tuvo/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/ROOT
# un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# crecimiento/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# 29/| <--NUM__NumForm=Digit|NumType=Card-- |/nmod
# %/| <--SYM__NumForm=Digit|NumType=Frac-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# por/| <--ADP__AdpType=Prep-- |/mark
# lo/| <--DET__Definite=Def|Number=Sing|PronType=Art-- |/det
# que/| <--PRON__PronType=Rel-- |/obl
# hemos/| <--AUX__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin-- |/aux
# hecho/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/acl
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# inversiones/| <--NOUN__Gender=Fem|Number=Plur-- |/obj
# acertadas/| <--ADJ__Gender=Fem|Number=Plur|VerbForm=Part-- |/amod
# con/| <--ADP__AdpType=Prep-- |/case
# una/| <--DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art-- |/det
# marca/| <--NOUN__Gender=Fem|Number=Sing-- |/obl
# icónica/| <--ADJ__Gender=Fem|Number=Sing-- |/amod
# ./| <--PUNCT__PunctType=Peri-- |/punct
# Después/| <--ADV___-- |/advmod
# de/| <--ADP__AdpType=Prep-- |/case
# cuatro/| <--NUM__Number=Plur|NumType=Card-- |/nummod
# años/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# de/| <--ADP__AdpType=Prep-- |/mark
# haber/| <--AUX__VerbForm=Inf-- |/aux
# adquirido/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/acl
# Don/| <--PROPN___-- |/obj
# Julio/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# hoy/| <--ADV___-- |/advmod
# es/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/cop
# líder/| <--NOUN__Number=Sing-- |/ccomp
# indiscutible/| <--ADJ__Number=Sing-- |/amod
# de/| <--ADP__AdpType=Prep-- |/case
# ventas/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
# en/| <--ADP__AdpType=Prep-- |/case
# México/| <--PROPN___-- |/nmod
# "/| <--PUNCT__PunctType=Quot-- |/punct
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# afirma/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# Erik/| <--PROPN___-- |/nsubj
# Seiersen/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# director/| <--NOUN__Gender=Masc|Number=Sing-- |/appos
# general/| <--ADJ__Number=Sing-- |/amod
# de/| <--ADP__AdpType=Prep-- |/case
# Diageo/| <--PROPN___-- |/nmod
# México/| <--PROPN___-- |/flat
# a/| <--ADP__AdpType=Prep-- |/case
# principios/| <--NOUN___-- |/fixed
# de/| <--ADP__AdpType=Prep-- |/fixed
# año/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# Recomendamos/| <--VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin-- |/ROOT
# :/| <--PUNCT__PunctType=Colo-- |/punct
# Brasil/| <--PROPN___-- |/nsubj
# reconoce/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/acl
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# denominación/| <--NOUN__Gender=Fem|Number=Sing-- |/obj
# de/| <--ADP__AdpType=Prep-- |/case
# origen/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# tequila/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# mexicano/| <--ADJ__Gender=Masc|Number=Sing-- |/amod
#
#
# /| <--_SP-- |/
# Parte/| <--PROPN___-- |/appos
# de/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# estrategia/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# firma/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# Beam/| <--PROPN___-- |/appos
# Inc/| <--PROPN___-- |/flat
# ./| <--PUNCT__PunctType=Peri-- |/punct
# y/| <--CCONJ___-- |/cc
# Suntory/| <--PROPN___-- |/nsubj
# Holdings/| <--PROPN___-- |/flat
# al/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/mark
# llegar/| <--VERB__VerbForm=Inf-- |/acl
# a/| <--ADP__AdpType=Prep-- |/case
# México/| <--PROPN___-- |/obl
# en/| <--ADP__AdpType=Prep-- |/case
# 2018/| <--NOUN__AdvType=Tim-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# es/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# explotar/| <--VERB__VerbForm=Inf-- |/ccomp
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# potencial/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# tequila/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# —que/| <--PROPN___-- |/appos
# representa/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ccomp
# cerca/| <--ADV___-- |/advmod
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# 38/| <--NUM__NumForm=Digit|NumType=Card-- |/obj
# %/| <--SYM__NumForm=Digit|NumType=Frac-- |/nmod
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# mercado/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# en/| <--ADP__AdpType=Prep-- |/case
# México—/| <--PROPN___-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# con/| <--ADP__AdpType=Prep-- |/case
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# marcas/| <--NOUN__Gender=Fem|Number=Plur-- |/obl
# Sauza/| <--PROPN___-- |/appos
# y/| <--CCONJ___-- |/cc
# Hornitos/| <--PROPN___-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# ambos/| <--NUM__Gender=Masc|Number=Plur|NumType=Card-- |/appos
# de/| <--ADP__AdpType=Prep-- |/case
# Casa/| <--PROPN___-- |/nmod
# Sauza/| <--PROPN___-- |/flat
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# “/| <--PROPN___-- |/obl
# Las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# empresas/| <--NOUN__Gender=Fem|Number=Plur-- |/nsubj
# multinacionales/| <--ADJ__Number=Plur-- |/amod
# con/| <--ADP__AdpType=Prep-- |/case
# portafolios/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# muy/| <--ADV___-- |/advmod
# grandes/| <--ADJ__Number=Plur-- |/amod
# y/| <--CCONJ___-- |/cc
# muy/| <--ADV___-- |/advmod
# completos/| <--ADJ__Gender=Masc|Number=Plur-- |/conj
# de/| <--ADP__AdpType=Prep-- |/case
# otras/| <--DET__Gender=Fem|Number=Plur|PronType=Ind-- |/det
# categorías/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
# que/| <--PRON__PronType=Rel-- |/nsubj
# tienen/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/acl
# presencia/| <--NOUN__Gender=Fem|Number=Sing-- |/obj
# en/| <--ADP__AdpType=Prep-- |/case
# muchos/| <--DET__Gender=Masc|Number=Plur|PronType=Ind-- |/det
# países/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# mundo/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# le/| <--PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs-- |/obj
# han/| <--AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# abierto/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/ROOT
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# puertas/| <--NOUN__Gender=Fem|Number=Plur-- |/obj
# al/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# tequila/| <--NOUN__Gender=Fem|Number=Sing-- |/obl
# ./| <--PUNCT__PunctType=Peri-- |/punct
# En/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# industria/| <--NOUN__Gender=Fem|Number=Sing-- |/obl
# tequilera/| <--ADJ__Gender=Fem|Number=Sing-- |/amod
# no/| <--ADV__Polarity=Neg-- |/advmod
# le/| <--PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs-- |/obj
# tenemos/| <--VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin-- |/ccomp
# miedo/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# a/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# competencia/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# es/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# bienvenida/| <--VERB__Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part-- |/advcl
# tanto/| <--ADV___-- |/cc
# nacional/| <--ADJ__Number=Sing-- |/nsubj
# como/| <--SCONJ___-- |/mark
# extranjera/| <--ADJ__Gender=Fem|Number=Sing-- |/amod
# ”/| <--PROPN___-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# comenta/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# Rodolfo/| <--PROPN___-- |/nsubj
# González/| <--PROPN___-- |/flat
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# presidente/| <--NOUN__Gender=Masc|Number=Sing-- |/appos
# de/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# Cámara/| <--PROPN___-- |/nmod
# Nacional/| <--PROPN___-- |/flat
# de/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Gender=Fem|Number=Sing|PronType=Art-- |/det
# Industria/| <--PROPN___-- |/flat
# Tequilera/| <--PROPN___-- |/flat
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# Por/| <--ADP__AdpType=Prep-- |/case
# su/| <--DET__Number=Sing|Person=3|Poss=Yes|PronType=Prs-- |/det
# parte/| <--NOUN__Gender=Fem|Number=Sing-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# Jose/| <--PROPN___-- |/nsubj
# Cuervo/| <--PROPN___-- |/flat
# continua/| <--ADJ__Gender=Fem|Number=Sing-- |/aux
# siendo/| <--AUX__VerbForm=Ger-- |/cop
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# tequilera/| <--NOUN__Gender=Fem|Number=Sing-- |/ROOT
# más/| <--ADV___-- |/advmod
# grande/| <--ADJ__Number=Sing-- |/amod
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# mundo/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# con/| <--ADP__AdpType=Prep-- |/case
# un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# crecimiento/| <--NOUN__Gender=Masc|Number=Sing-- |/obl
# total/| <--ADJ__Number=Sing-- |/amod
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# volumen/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# 3.8/| <--PROPN___-- |/nummod
# %/| <--SYM__NumForm=Digit|NumType=Frac-- |/nmod
# durante/| <--ADP__AdpType=Prep-- |/case
# 2018/| <--NOUN__AdvType=Tim-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# que/| <--PRON__PronType=Rel-- |/nsubj
# cerró/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/acl
# con/| <--ADP__AdpType=Prep-- |/case
# 21.3/| <--NUM__NumForm=Digit-- |/nummod
# millones/| <--NOUN__Gender=Masc|Number=Plur-- |/obl
# de/| <--ADP__AdpType=Prep-- |/case
# cajas/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# nueve/| <--NUM__Number=Plur|NumType=Card-- |/nummod
# litros/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# y/| <--CCONJ___-- |/cc
# ventas/| <--NOUN__Gender=Fem|Number=Plur-- |/conj
# netas/| <--ADJ__Gender=Fem|Number=Plur-- |/amod
# de/| <--ADP__AdpType=Prep-- |/case
# 28,158/| <--NUM__NumForm=Digit-- |/nummod
# millones/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# pesos/| <--NOUN__NumForm=Digit-- |/nmod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# en/| <--ADP__AdpType=Prep-- |/case
# comparación/| <--NOUN__Gender=Fem|Number=Sing-- |/obl
# con/| <--ADP__AdpType=Prep-- |/case
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# mismo/| <--DET__Gender=Masc|Number=Sing|PronType=Ind-- |/det
# periodo/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# de/| <--ADP__AdpType=Prep-- |/case
# 2017/| <--NOUN__AdvType=Tim-- |/nmod
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# La/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# producción/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
# total/| <--ADJ__Number=Sing-- |/amod
# al/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# cierre/| <--NOUN__Gender=Masc|Number=Sing-- |/nmod
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# año/| <--NOUN__AdvType=Tim-- |/nmod
# pasado/| <--ADJ__Gender=Masc|Number=Sing|VerbForm=Part-- |/amod
# fue/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/cop
# de/| <--ADP__AdpType=Prep-- |/case
# 308.1/| <--NUM__NumForm=Digit-- |/nummod
# millones/| <--NOUN__Gender=Masc|Number=Plur-- |/ROOT
# de/| <--ADP__AdpType=Prep-- |/case
# litros/| <--NOUN__Gender=Masc|Number=Plur-- |/nmod
# ./| <--PUNCT__PunctType=Peri-- |/punct
# En/| <--ADP__AdpType=Prep-- |/case
# México/| <--PROPN___-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# existen/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# cerca/| <--ADV___-- |/advmod
# de/| <--ADP__AdpType=Prep-- |/case
# 150/| <--NUM__NumForm=Digit-- |/nummod
# destilerías/| <--NOUN__Gender=Fem|Number=Plur-- |/nsubj
# en/| <--ADP__AdpType=Prep-- |/case
# México/| <--PROPN___-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# mayoría/| <--NOUN__Gender=Fem|Number=Sing-- |/appos
# ubicada/| <--ADJ__Gender=Fem|Number=Sing|VerbForm=Part-- |/amod
# en/| <--ADP__AdpType=Prep-- |/case
# Jalisco/| <--PROPN___-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# aunque/| <--SCONJ___-- |/mark
# también/| <--ADV___-- |/advmod
# se/| <--PRON__Person=3-- |/obj
# produce/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/advcl
# en/| <--ADP__AdpType=Prep-- |/case
# menor/| <--ADJ__Number=Sing-- |/amod
# proporción/| <--NOUN__Gender=Fem|Number=Sing-- |/obl
# en/| <--ADP__AdpType=Prep-- |/case
# Guanajuato/| <--PROPN___-- |/obl
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# Michoacán/| <--PROPN___-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# Nayarit/| <--PROPN___-- |/conj
# y/| <--CCONJ___-- |/cc
# Tamaulipas/| <--PROPN___-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# generando/| <--VERB__VerbForm=Ger-- |/advcl
# cerca/| <--ADV___-- |/advmod
# de/| <--ADP__AdpType=Prep-- |/case
# 70,000/| <--NUM__NumForm=Digit-- |/nummod
# empleos/| <--NOUN__Gender=Masc|Number=Plur-- |/obj
# ./| <--PUNCT__PunctType=Peri-- |/punct
#
#
# /| <--_SP-- |/
# La/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# fuerza/| <--NOUN__Gender=Fem|Number=Sing-- |/nsubj
# de/| <--ADP__AdpType=Prep-- |/case
# esta/| <--DET__Gender=Fem|Number=Sing|PronType=Dem-- |/det
# categoría/| <--NOUN__Gender=Fem|Number=Sing-- |/nmod
# ha/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# sido/| <--AUX__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/punct
# tal/| <--DET__Number=Sing|PronType=Dem-- |/mark
# que/| <--SCONJ___-- |/fixed
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# pasado/| <--ADJ__Gender=Masc|Number=Sing|VerbForm=Part-- |/amod
# 16/| <--NUM__NumForm=Digit|NumType=Card-- |/obl
# de/| <--ADP__AdpType=Prep-- |/case
# marzo/| <--NOUN___-- |/compound
# se/| <--PRON___-- |/obj
# celebró/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/ccomp
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# primer/| <--ADJ__Gender=Masc|Number=Sing|NumType=Ord-- |/amod
# Día/| <--PROPN___-- |/nsubj
# Nacional/| <--PROPN___-- |/flat
# del/| <--ADP__AdpType=Preppron|Gender=Masc|Number=Sing-- |/case
# Tequila.“Aquí/| <--PROPN___-- |/nmod
# lo/| <--DET__Definite=Def|Number=Sing|PronType=Art-- |/det
# que/| <--PRON__PronType=Rel-- |/obj
# hemos/| <--AUX__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin-- |/aux
# logrado/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/advcl
# es/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/cop
# darle/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin-- |/ROOT
# un/| <--DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art-- |/det
# sentido/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# más/| <--ADV___-- |/advmod
# nacional/| <--ADJ__Number=Sing-- |/amod
# y/| <--CCONJ___-- |/cc
# doméstico/| <--ADJ__Gender=Masc|Number=Sing-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# pero/| <--CCONJ___-- |/cc
# ha/| <--AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/aux
# levantado/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/conj
# más/| <--ADV___-- |/advmod
# interés/| <--NOUN__Gender=Masc|Number=Sing-- |/obj
# de/| <--ADP__AdpType=Prep-- |/case
# otras/| <--DET__Gender=Fem|Number=Plur|PronType=Ind-- |/det
# asociaciones/| <--NOUN__Gender=Fem|Number=Plur-- |/nmod
# para/| <--ADP__AdpType=Prep-- |/mark
# participar/| <--VERB__VerbForm=Inf-- |/advcl
# ./| <--PUNCT__PunctType=Peri-- |/punct
# Se/| <--PRON___-- |/expl:pass
# habla/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# de/| <--ADP__AdpType=Prep-- |/case
# México/| <--PROPN___-- |/obj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# de/| <--ADP__AdpType=Prep-- |/case
# todas/| <--DET__Gender=Fem|Number=Plur|PronType=Ind-- |/det
# las/| <--DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art-- |/det
# bondades/| <--NOUN__Gender=Fem|Number=Plur-- |/obl
# que/| <--PRON__PronType=Rel-- |/obj
# tiene/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/acl
# nuestro/| <--DET__Gender=Masc|Number=Sing|Number[psor]=Plur|Person=1|Poss=Yes|PronType=Prs-- |/det
# país/| <--NOUN__Gender=Masc|Number=Sing-- |/nsubj
# y/| <--CCONJ___-- |/cc
# el/| <--DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art-- |/det
# tequila/| <--NOUN__Gender=Masc|Number=Sing-- |/conj
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# entre/| <--ADP__AdpType=Prep-- |/case
# ellos/| <--PRON__Gender=Masc|Number=Plur|Person=3|PronType=Prs-- |/obl
# se/| <--PRON__Person=3-- |/obj
# caracteriza/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/advcl
# por/| <--ADP__AdpType=Prep-- |/case
# la/| <--DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art-- |/det
# versatilidad/| <--NOUN__Gender=Fem|Number=Sing-- |/obj
# que/| <--PRON__PronType=Rel-- |/obj
# hace/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/acl
# que/| <--SCONJ___-- |/mark
# sea/| <--AUX__Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/cop
# mundialmente/| <--ADV___-- |/advmod
# tan/| <--ADV___-- |/advmod
# respetado/| <--ADJ__Gender=Masc|Number=Sing|VerbForm=Part-- |/ccomp
# y/| <--CCONJ___-- |/cc
# reconocido/| <--VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part-- |/conj
# ./| <--PUNCT__PunctType=Peri-- |/punct
# Pocas/| <--DET__Gender=Fem|Number=Plur|PronType=Ind-- |/det
# bebidas/| <--NOUN__Gender=Fem|Number=Plur-- |/nsubj
# tienen/| <--VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin-- |/ccomp
# esas/| <--DET__Gender=Fem|Number=Plur|PronType=Dem-- |/det
# cualidades/| <--NOUN__Gender=Fem|Number=Plur-- |/obj
# ”/| <--PROPN___-- |/amod
# ,/| <--PUNCT__PunctType=Comm-- |/punct
# añade/| <--VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin-- |/ROOT
# González/| <--PROPN___-- |/nsubj
# ./| <--PUNCT__PunctType=Peri-- |/punct
